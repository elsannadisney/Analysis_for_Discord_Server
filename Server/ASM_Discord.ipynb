# %%
# !pip install konlpy
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 31.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.6/465.6 KB 17.6 MB/s eta 0:00:00
# ...
# Selecting previously unselected package fonts-nanum-extra.
# (Reading database ... 128126 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum-extra_20180306-3_all.deb ...
# Unpacking fonts-nanum-extra (20180306-3) ...
# Selecting previously unselected package fonts-nanum.
# Preparing to unpack .../fonts-nanum_20180306-3_all.deb ...
# Unpacking fonts-nanum (20180306-3) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-2_all.deb ...
# Unpacking fonts-nanum-coding (2.5-2) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-7_all.deb ...
# ...

# %%
import matplotlib.font_manager as fm
sys_font = fm.findSystemFonts()

[f for f in sys_font if 'Nanum' in f]
# Out:
# ['/usr/share/fonts/truetype/nanum/NanumMyeongjoEcoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicLight.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareEB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicUltraLight.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBrush.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareRoundEB.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumSquareR.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumMyeongjoExtraBold.ttf',
#  '/usr/share/fonts/truetype/nanum/NanumGothicLight.ttf',
# ...

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
fm._rebuild()
# Out:
# NanumGothic

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np

# %%
#아사모

# %%
from konlpy.tag import Okt
import re
with open('파일링크.txt', 'r', encoding='utf-8') as f:
  content = f.read()
p = re.compile("[\Wa-zA-Z0-9_]+")
content = re.sub(p, "", content)
okt = Okt()
morphs = okt.pos(content)
words = [word for word, pos in morphs if pos =="Noun"]
print(words)
# Out:
# ['아사', '모', '찡긋', '도리', '왜닉', '이개', '도리', '봇', '개새끼', '야천', '신분', '주제', '감히', '분', '존함', '언급', '클래식', '다가', '튀어', '난', '인물', '프로', '프로', '물', '맑은', '물', '찡긋', '오이', '북미', '새끼', '병신', '한국인', '딜러', '새끼', '가내', '킬금', '정치', '함', '라인', '못해', '라인', '이안', '새벽', '지금', '새벽', '방금', '연속', '애초', '글', '한국', '아이피', '한국인', '매칭', '줌욕', '함', '새벽', '왜욕', '해메', '이충', '존나', '못', '게임', '처음', '끝', '가킬', '금', '한국인', '때', '내', '초창', '때', '지금', '외국인', '줄', '게임', '때', '한남', '말', '목소리', '존나', '패', '킬금', '입', '뭐', '하자', '딜러', '새끼', '꼬추', '정치', '질', '딜러', '겜못', '바로', '경쟁', '구간', '시', '메트라', '금', '빼', '병신', '구간', '대가리', '갑', '북미', '도', '새끼', '한국', '놈', '미국', '놈', '병신', '일단', '브실', '머', '리가', '한국말', '외국인', '것', '시', '메트라', '그냥', '트롤', '픽', '줄', '국문', '병신', '과학', '금', '지랄', '함겜', '겜', '라인', '킬뎃', '거의', '뭐', '딜러', '리퍼', '경쟁', '킬뎃', '임배', '데스', '매치', '클래식', '레벨', '안', '모드', '왜', '우울증', '전투', '과정', '클래식', '화가', '남', '카라', '킨해', '레벨', '지랄', '가라', '킨', '어려움', '인칭', '난', '요구', '게', '우울증', '환자', '말안', '면알', '지문', '재앙', '도
# ...

# %%
from collections import Counter
stopwords = ['[',']','LGBT#2417','도리봇#3725','찡긋#5913','도리봇','도리','Re Re#3138','봇말좀','찡긋','봇입','배하','봇욕','봇말','감지','한문','세탁기','하층','캐시','우드','당신','우리']
result = [x for x in words if x not in stopwords and len(x) > 1]
print(result)

c = Counter(result)
print(c.most_common(10))
# Out:
# ['아사', '왜닉', '이개', '개새끼', '야천', '신분', '주제', '감히', '존함', '언급', '클래식', '다가', '튀어', '인물', '프로', '프로', '맑은', '오이', '북미', '새끼', '병신', '한국인', '딜러', '새끼', '가내', '킬금', '정치', '라인', '못해', '라인', '이안', '새벽', '지금', '새벽', '방금', '연속', '애초', '한국', '아이피', '한국인', '매칭', '줌욕', '새벽', '왜욕', '해메', '이충', '존나', '게임', '처음', '가킬', '한국인', '초창', '지금', '외국인', '게임', '한남', '목소리', '존나', '킬금', '하자', '딜러', '새끼', '꼬추', '정치', '딜러', '겜못', '바로', '경쟁', '구간', '메트라', '병신', '구간', '대가리', '북미', '새끼', '한국', '미국', '병신', '일단', '브실', '리가', '한국말', '외국인', '메트라', '그냥', '트롤', '국문', '병신', '과학', '지랄', '함겜', '라인', '킬뎃', '거의', '딜러', '리퍼', '경쟁', '킬뎃', '임배', '데스', '매치', '클래식', '레벨', '모드', '우울증', '전투', '과정', '클래식', '화가', '카라', '킨해', '레벨', '지랄', '가라', '어려움', '인칭', '요구', '우울증', '환자', '말안', '면알', '지문', '재앙', '봇패', '드립', '삭제', '방해', '기전', '처신', '인칭', '가라', '씨발', '자구', '거임', '인칭', '야호', '인칭', '획득', '인칭', '리몬', '인칭', '라이', '배그', '인칭', '때문', '인칭', '베타', '출시', '자마자', '그거', '배틀로얄', '장르', '때문', '콜옵', '입지', '인칭', '콜옵', '자체', '가운', '그때', '경쟁', '매너', '유저'
# ...

# %%
from wordcloud.wordcloud import FONT_PATH
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from os import path

FONT_PATH = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"  

text = " ".join(result)
wordcloud = WordCloud(
    max_font_size=100, 
    max_words=55, 
    background_color= '#FFFBFA', 
    relative_scaling=.5, 
    width = 500,
    height = 300,
    font_path=FONT_PATH).generate(text)

plt.figure()
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("ASM.png")

# %%
nouns = result
nouns
# Out:
# ['아사',
#  '왜닉',
#  '이개',
#  '개새끼',
#  '야천',
#  '신분',
#  '주제',
#  '감히',
#  '존함',
#  '언급',
#  '클래식',
#  '다가',
#  '튀어',
#  '인물',
#  '프로',
#  '프로',
#  '맑은',
#  '오이',
#  '북미',
#  '새끼',
#  '병신',
#  '한국인',
#  '딜러',
#  '새끼',
#  '가내',
#  '킬금',
#  '정치',
#  '라인',
#  '못해',
#  '라인',
#  '이안',
#  '새벽',
#  '지금',
#  '새벽',
#  '방금',
#  '연속',
#  '애초',
#  '한국',
#  '아이피',
#  '한국인',
#  '매칭',
#  '줌욕',
#  '새벽',
#  '왜욕',
#  '해메',
#  '이충',
#  '존나',
#  '게임',
#  '처음',
#  '가킬',
#  '한국인',
#  '초창',
#  '지금',
#  '외국인',
#  '게임',
#  '한남',
#  '목소리',
#  '존나',
#  '킬금',
#  '하자',
#  '딜러',
#  '새끼',
#  '꼬추',
#  '정치',
#  '딜러',
#  '겜못',
#  '바로',
#  '경쟁',
#  '구간',
#  '메트라',
#  '병신',
#  '구간',
#  '대가리',
#  '북미',
#  '새끼',
#  '한국',
#  '미국',
#  '병신',
#  '일단',
#  '브실',
#  '리가',
#  '한국말',
#  '외국인',
#  '메트라',
#  '그냥',
#  '트롤',
#  '국문',
#  '병신',
#  '과학',
#  '지랄',
#  '함겜',
#  '라인',
#  '킬뎃',
#  '거의',
#  '딜러',
#  '리퍼',
#  '경쟁',
#  '킬뎃',
#  '임배',
#  '데스',
#  '매치',
#  '클래식',
#  '레벨',
#  '모드',
#  '우울증',
#  '전투',
#  '과정',
#  '클래식',
#  '화가',
# ...

# %%
import pandas as pd
df_word = pd.DataFrame({'word' : nouns})
df_word
# Out:
#        word
# 0        아사
# 1        왜닉
# 2        이개
# 3       개새끼
# 4        야천
# ...     ...
# 28831    건가
# 28832  이중인격
# 28833    쿠팡
# 28834    진짜
# 28835  이중인격
#
# [28836 rows x 1 columns]

# %%
df_word['count'] = df_word['word'].str.len() 
df_word
# Out:
#        word  count
# 0        아사      2
# 1        왜닉      2
# 2        이개      2
# 3       개새끼      3
# 4        야천      2
# ...     ...    ...
# 28831    건가      2
# 28832  이중인격      4
# 28833    쿠팡      2
# 28834    진짜      2
# 28835  이중인격      4
#
# [28836 rows x 2 columns]

# %%
df_word = df_word.query('count >= 2')
df_word.sort_values('count')
# Out:
#            word  count
# 0            아사      2
# 18197        사실      2
# 18196        까비      2
# 18195        그때      2
# 18193        재화      2
# ...         ...    ...
# 14584   드임랜쿼드는딜      7
# 26679   런거지뭐즐겜러      7
# 6768    슈십니꽈훠훠훠      7
# 27850   코끼리바다표범      7
# 9058   튜버한명허버허버      8
#
# [28836 rows x 2 columns]

# %%
df_word = df_word.groupby('word', as_index=False).agg(n = ('word', 'count')).sort_values('n', ascending = False) 
df_word
# Out:
#      word    n
# 2913   사람  536
# 372    게임  252
# 6424   호선  183
# 3051   생각  157
# 5371   진짜  144
# ...   ...  ...
# 1728   라사    1
# 4077  옵챗걔    1
# 4078   옵치    1
# 4079   옷눈    1
# 3262  손흥민    1
#
# [6525 rows x 2 columns]

# %%
top20 = df_word.head(20) 
top20
# Out:
#      word    n
# 2913   사람  536
# 372    게임  252
# 6424   호선  183
# 3051   생각  157
# 5371   진짜  144
# 2971   삭제  144
# 3818   언급  139
# 4007   오늘  128
# 3042   새끼  127
# 5687   컴배  122
# 5059   제발  107
# 2587   병신  106
# 6094   표현   98
# 1678   때문   94
# 5277   지금   94
# 3384   시간   93
# 336    걸레   93
# 5116   존나   91
# 1170   뉴스   89
# 746    그냥   89

# %%
font = 'NanumBarunGothic.ttf'

# %%
dic_word = df_word .set_index('word').to_dict()['n']
dic_word
# Out:
# {'사람': 536,
#  '게임': 252,
#  '호선': 183,
#  '생각': 157,
#  '진짜': 144,
#  '삭제': 144,
#  '언급': 139,
#  '오늘': 128,
#  '새끼': 127,
#  '컴배': 122,
#  '제발': 107,
#  '병신': 106,
#  '표현': 98,
#  '때문': 94,
#  '지금': 94,
#  '시간': 93,
#  '걸레': 93,
#  '존나': 91,
#  '뉴스': 89,
#  '그냥': 89,
#  '인칭': 87,
#  '친구': 81,
#  '해당': 80,
#  '그거': 80,
#  '친목': 79,
#  '서버': 79,
#  '닉네임': 78,
#  '자격': 77,
#  '문제': 74,
#  '이름': 73,
#  '애플': 72,
#  '사용': 70,
#  '추천': 70,
#  '자살': 70,
#  '삼성': 70,
#  '시발': 68,
#  '자기': 67,
#  '통일체': 66,
#  '사실': 65,
#  '구입': 65,
#  '용해': 65,
#  '그때': 63,
#  '목표': 62,
#  '지랄': 61,
#  '소리': 59,
#  '코로나': 58,
#  '모바일': 57,
#  '라운드': 57,
#  '안함': 56,
#  '도안': 56,
#  '다른': 56,
#  '배틀': 55,
#  '워치': 55,
#  '그녀': 54,
#  '존못': 52,
#  '개조': 52,
#  '음식': 52,
#  '단어': 51,
#  '계속': 51,
#  '주가': 51,
#  '성격': 50,
#  '소유자': 49,
#  '테슬라': 49,
#  '공부': 49,
#  '보고': 49,
#  '서로': 48,
#  '아이폰': 48,
#  '제시': 48,
#  '인생': 47,
#  '오버': 47,
#  '인간': 45,
#  '순화': 45,
#  '유저': 45,
#  '모습': 44,
#  '잘못': 43,
# ...

# %%
from wordcloud import WordCloud
wc = WordCloud(random_state = 100,
               font_path = font,
               width = 400,
               height = 400,
               background_color = '#fefefe')

# %%
img_wordcloud = wc.generate_from_frequencies(dic_word)

plt.figure(figsize = (10, 10))
plt.axis('off')
plt.imshow(img_wordcloud)

# %%
img_wordcloud.to_file("ASM_02.png")
